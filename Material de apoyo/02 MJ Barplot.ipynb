# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Gráficos de Barras
#
# **¿Qué es un Gráfico de Barra (barplot)?**
#
# Los gráficos de barra o barplots son uno de los tipos de gráficos más utilizados. Nos permiten mostrar la relación entre una variable numérica y una categórica.

# %% [markdown]
# Para este notebook, usaremos la siguiente base de datos para aprender a crear gráficos de barra, que habla sobre automóviles y algunos de sus parámetros:
#
#
#   Número |Nombre  | Descripción
# ---------|--------|------------------
#  1       |mpg     | Miles/(US) gallon
#  2       |cyl     | Number of cylinders
#  3       |disp    | Displacement (cu.in.)
#  4       |hp      | Gross horsepower
#  5       |drat    | Rear axle ratio
#  6       |wt      | Weight (1000 lbs)
#  7       |qsec    | 1/4 mile time
#  8       |vs      | Engine (0 = V-shaped, 1 = straight)
#  9       |am      | Transmission (0 = automatic, 1 = manual)
#  10      |gear    | Number of forward gears
#  11      |carb    | Number of carburetors
#
# Los datos se extrajeron de la revista estadounidense Motor Trend de 1974 y comprenden el consumo de combustible y 10 aspectos del diseño y el rendimiento del automóvil para 32 automóviles (modelos 1973-74).
#
# - 1	mpg	Millas por galón (Miles per Gallon), mide la eficiencia del consumo de combustible
# - 2	cyl	Número de cilindros del motor
# - 3	disp	Cilindrada del motor (pulgadas cúbicas, cu.in.)
# - 4	hp	Potencia bruta del motor (Gross Horsepower)
# - 5	drat	Relación del eje trasero (Rear Axle Ratio)
# - 6	wt	Peso del vehículo (en miles de libras)
# - 7	qsec	Tiempo en recorrer 1/4 de milla
# - 8	vs	Tipo de motor (0 = en V, 1 = en línea)
# - 9	am	Tipo de transmisión (0 = automática, 1 = manual)
# - 10	gear	Número de marchas hacia adelante
# - 11	carb	Número de carburadores

# %%
# Recordemos instalar pydataset
# !pip install pydataset
# Out:
# Collecting pydataset
#   Downloading pydataset-0.2.0.tar.gz (15.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 61.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from pydataset) (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas->pydataset) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->pydataset) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->pydataset) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->pydataset) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->pydataset) (1.17.0)
# Building wheels for collected packages: pydataset
#   Building wheel for pydataset (setup.py) ... done
#   Created wheel for pydataset: filename=pydataset-0.2.0-py3-none-any.whl size=15939415 sha256=45e37d79f18f9602fa1a07d1307d255d8b88897985508da8201c975059e0c68d
#   Stored in directory: /root/.cache/pip/wheels/4c/82/ad/f04abc617222b10438b1285ab9b5cfaecd180c10a7c81cff54
# Successfully built pydataset
# Installing collected packages: pydataset
# Successfully installed pydataset-0.2.0

# %%
from pydataset import data
print(data())
df=data()
print(type(df))
df.to_csv('salida.csv')
# Out:
#         dataset_id                                             title
# 0    AirPassengers       Monthly Airline Passenger Numbers 1949-1960
# 1          BJsales                 Sales Data with Leading Indicator
# 2              BOD                         Biochemical Oxygen Demand
# 3     Formaldehyde                     Determination of Formaldehyde
# 4     HairEyeColor         Hair and Eye Color of Statistics Students
# ..             ...                                               ...
# 752        VerbAgg                  Verbal Aggression item responses
# 753           cake                 Breakage Angle of Chocolate Cakes
# 754           cbpp                 Contagious bovine pleuropneumonia
# 755    grouseticks  Data on red grouse ticks from Elston et al. 2001
# 756     sleepstudy       Reaction times in a sleep deprivation study
#
# [757 rows x 2 columns]
# <class 'pandas.core.frame.DataFrame'>

# %%
print(data('dogs', show_doc=True))
dogs=data("dogs")
print(dogs.head(10))
print(dogs.shape)
print(dogs.info())
# Out:
# dogs
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ##  Cardiac Data for Domestic Dogs
#
# ### Description
#
# The `dogs` data frame has 7 rows and 2 columns.
#
# Data on the cardiac oxygen consumption and left ventricular pressure were
# gathered on 7 domestic dogs.
#
# ### Usage
#
#     dogs
#
# ### Format
#
# This data frame contains the following columns:
#
# mvo
#
# Cardiac Oxygen Consumption
#
# lvp
#
# Left Ventricular Pressure
#
# ### References
#
# Davison, A. C. and Hinkley, D. V. (1997) _Bootstrap Methods and Their
# Application_. Cambridge University Press.
#
#
# None
#    mvo  lvp
# 1   78   32
# 2   92   33
# 3  116   45
# 4   90   30
# 5  106   38
# 6   78   24
# 7   99   44
# (7, 2)
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, 1 to 7
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   mvo     7 non-null      int64
#  1   lvp     7 non-null      int64
# dtypes: int64(2)
# memory usage: 168.0 bytes
# None

# %%
print(data('mtcars', show_doc=True))

mtcars = data("mtcars")
mtcars.head(5)
# Out:
# mtcars
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Motor Trend Car Road Tests
#
# ### Description
#
# The data was extracted from the 1974 _Motor Trend_ US magazine, and comprises
# fuel consumption and 10 aspects of automobile design and performance for 32
# automobiles (1973–74 models).
#
# ### Usage
#
#     mtcars
#
# ### Format
#
# A data frame with 32 observations on 11 variables.
#
# [, 1]
#
# mpg
#
# Miles/(US) gallon
#
# [, 2]
#
# cyl
#
# Number of cylinders
#
# [, 3]
#
# disp
#
# Displacement (cu.in.)
#
# [, 4]
#
# hp
#
# Gross horsepower
#
# [, 5]
#
# drat
#
# Rear axle ratio
#
# [, 6]
#
# wt
#
# Weight (lb/1000)
#
# [, 7]
#
# qsec
#
# 1/4 mile time
#
# [, 8]
#
# vs
#
# V/S
#
# [, 9]
#
# am
#
# Transmission (0 = automatic, 1 = manual)
#
# [,10]
#
# gear
#
# Number of forward gears
#
# [,11]
#
# carb
#
# Number of carburetors
#
# ### Source
#
# Henderson and Velleman (1981), Building multiple regression models
# interactively. _Biometrics_, **37**, 391–411.
#
# ### Examples
#
#     require(graphics)
#     pairs(mtcars, main = "mtcars data")
#     coplot(mpg ~ disp | as.factor(cyl), data = mtcars,
#            panel = panel.smooth, rows = 1)
#
#
# None
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2

# %%
print(mtcars.shape)
print(mtcars.info())
# Out:
# (32, 11)
# <class 'pandas.core.frame.DataFrame'>
# Index: 32 entries, Mazda RX4 to Volvo 142E
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   mpg     32 non-null     float64
#  1   cyl     32 non-null     int64
#  2   disp    32 non-null     float64
#  3   hp      32 non-null     int64
#  4   drat    32 non-null     float64
#  5   wt      32 non-null     float64
#  6   qsec    32 non-null     float64
#  7   vs      32 non-null     int64
#  8   am      32 non-null     int64
#  9   gear    32 non-null     int64
#  10  carb    32 non-null     int64
# dtypes: float64(5), int64(6)
# memory usage: 4.0+ KB
# None

# %% [markdown]
# ## Nuestro primer gráfico de barras
#
# **¿Cuántos autos tienen transmisión de tipo automático vs manual?**
#
# 1. Los gráficos de barra nos permiten responder esta pregunta fácilmente de manera visual.
# 2. Para esto solo debemos graficar la variable categórica ``am`` que contiene el tipo de transmisión (**0: automática, 1:manual**) vs la variable númerica correspondiente al conteo de estas categorias.
# 3. Antes de graficar pre-procesaremos los datos para que la información sea más clara tanto como para nosotros, como para el lector y el computador.

# %%
#metodo map sobre series
x = pd.Series([1,2,3], index=['uno', 'dos', 'tres'])
print(x.index)
print(x.values)
x
# Out:
# Index(['uno', 'dos', 'tres'], dtype='object')
# [1 2 3]
# uno     1
# dos     2
# tres    3
# dtype: int64

# %%
y=x.map({1:'OTROUNO', 2:'OTRODOS', 3:'OTROTRES'})
y
# Out:
# uno      OTROUNO
# dos      OTRODOS
# tres    OTROTRES
# dtype: object

# %%
# En esta celda reemplazamos los 0 y 1 por Automático y Manual respectivamente.
#mtcars = data("mtcars")
mtcars['am'] = mtcars['am'].map({0:'Automático', 1:'Manual'})
mtcars.head(20)
#mtcars.index
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1
# Merc 450SE           16.4    8  275.8  180  3.07  4.070  17.40   0
# Merc 450SL           17.3    8  275.8  180  3.07  3.730  17.60   0
# Merc 450SLC          15.2    8  275.8  180  3.07  3.780  18.00   0
# Cadillac Fleetwood   10.4    8  472.0  205  2.93  5.250  17.98   0
# Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0
# Chrysler Imperial    14.7    8  440.0  230  3.23  5.345  17.42   0
# Fiat 128             32.4    4   78.7   66  4.08  2.200  19.47   1
# Honda Civic          30.4    4   75.7   52  4.93  1.615  18.52   1
# Toyota Corolla       33.9    4   71.1   65  4.22  1.835  19.90   1
#
#                              am  gear  carb
# Mazda RX4                Manual     4     4
# Mazda RX4 Wag            Manual     4     4
# Datsun 710               Manual     4     1
# Hornet 4 Drive       Automático     3     1
# Hornet Sportabout    Automático     3     2
# Valiant              Automático     3     1
# Duster 360           Automático     3     4
# Merc 240D            Automático     4     2
# Merc 230             Automático     4     2
# Merc 280             Automático     4     4
# Merc 280C            Automático     4     4
# Merc 450SE           Automático     3     3
# Merc 450SL           Automático     3     3
# Merc 450SLC          Automático     3     3
# Cadillac Fleetwood   Automático     3     4
# Lincoln Continental  Automático     3     4
# Chrysler Imperial    Automático     3     4
# Fiat 128                 Manual     4     1
# Honda Civic              Manual     4     2
# Toyota Corolla           Manual     4     1

# %% [markdown]
# ## Quiz 1: ¿qué pasa si lo ejecuto nuevamente?

# %% [markdown]
# **Nuestro primer gráfico de barras:**
#
# Estamos casi listos para graficar la información requerida. Sin embargo, note que en nuestra base de datos no existe explícitamente una columna que tenga el número de autos con transmisión automática o  manual. Para solucionar esto hay tres opciones.

# %% [markdown]
# ## Opción 1 - Matplotlib
#
# Nos creamos una tabla de frecuencias que contenga la información que queremos graficar. Para esto utilizamos `groupby()`, y contamos cuantos automóviles automáticos y manuales hay.

# %%
mtcars_grouped = mtcars['am'].groupby(mtcars["am"]).count()
print(mtcars_grouped)
#print(type(mtcars_grouped))
#print(mtcars_grouped.shape)
#print('-------------------------------')
#print(mtcars_grouped.values)
# Out:
# am
# Automático    19
# Manual        13
# Name: am, dtype: int64

# %% [markdown]
# Ahora, podemos usar la función de `matplotlib` para hacer gráficos de barras. Veamos un ejemplo.

# %%
plt.title("Cantidad de Autos Automáticos y Manuales")
plt.bar(mtcars_grouped.keys(), mtcars_grouped)
#plt.show()
#plt.bar(mtcars_grouped.index, mtcars_grouped.values)
#plt.show()
#print(mtcars_grouped.keys())
#print(mtcars_grouped.index)
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# Recordemos que además podemos hacer este gráfico con el estilo XKCD.

# %% [markdown]
# ## Quiz 2: qué diferencia hay entre .keys() y .index()

# %%
with plt.xkcd():
    plt.title("Cantidad de Autos Automáticos y Manuales")
    plt.bar(mtcars_grouped.keys(), mtcars_grouped)
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.

# %% [markdown]
# La desventaja de esto, es que a veces queremos simplemente pasar el DataFrame, y que el lenguaje se encargue de hacer la visualización por nosotros. Por lo mismo, vamos a ver dos opciones más automáticas.

# %% [markdown]
# ## Quiz 3: ¿a qué se refiere especificamente la frase anterior?

# %% [markdown]
# ## Opcion 2 - Función de Pandas
#
# Le decimos a `Pandas` que se encargue de contar por nosotros. Para esto utilizaremos la función `value_counts()` que le indica al "eje y" que debe contar las frecuencias observadas para las categorias de la variable categorica asignada al "eje x".

# %%
ax = mtcars["am"].value_counts().plot(kind="bar")
ax.set_ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
# Cabe destacar que `Pandas`, por debajo, está usando `matplotlib`. Por lo mismo, en el caso de querer las proporciones, podemos ejecutar el siguiente código, que mezcla código de `matplotlib` con la instrucción de `Pandas`.

# %% [markdown]
# ## Quiz 4: ¿Qué estamos mostrando en el grafico anterior?

# %%
import matplotlib.ticker as mtick

ax = mtcars["am"].value_counts(normalize=True).plot(kind="bar") #normalize=true permite calcualr las fecuencias relativas
ax.set_ylabel("count/sum(count)")
ax.set_xlabel(mtcars["am"].name);

# Esta función permite transaformar la escala del eje y a procentajes
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1.0))

# %% [markdown]
# ## Opción 3 - Seaborn
#
# La tercera opción es utilizar **Seaborn**, una librería que se construyó en base a `matplotlib`. Esta librería está más orientada a _Data Science_, y por lo mismo, provee una interfaz directa para trabajar con DataFrames.

# %%
import seaborn as sns

ax = sns.countplot(x="am", data=mtcars)

# %% [markdown]
# Además, en `seaborn` podemos cambiar el tema (ojo, hay formas de hacer esto también en `matplotlib`).
#
# https://seaborn.pydata.org/generated/seaborn.set_theme.html

# %%
sns.set_theme(style="whitegrid", palette="pastel", )
ax = sns.countplot(x="am", data=mtcars)

# %% [markdown]
# O el tema por defecto. Puedes ver [más detalles aquí](https://seaborn.pydata.org/generated/seaborn.set_theme.html).

# %%
sns.set_theme()
ax = sns.countplot(x="am", data=mtcars)

# %% [markdown]
# ## Quiz 5: ¿Cuál de los 3 métodos visto le parece mas directo?

# %% [markdown]
# # Utilizando 2 o más variables categóricas

# %% [markdown]
# Podemos utilizar los gráficos de barra para estudiar más de una variable categórica al mismo tiempo. En este ejemplo consideremos la variable `vs` que denota el tipo de motor: (**0: V-shaped, 1:Straight**).

# %%
# En este módulo reemplazamos los 0 y 1 por V-shaped y Straight respectivamente.
mtcars['vs'] = mtcars['vs'].map({0: 'V-shaped', 1: 'Straight'})
mtcars.head(5)
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec   vs          am  \
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46  NaN      Manual
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02  NaN      Manual
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61  NaN      Manual
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44  NaN  Automático
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02  NaN  Automático
#
#                    gear  carb
# Mazda RX4             4     4
# Mazda RX4 Wag         4     4
# Datsun 710            4     1
# Hornet 4 Drive        3     1
# Hornet Sportabout     3     2

# %% [markdown]
# ## función pd.get_dummies sobre variables categoricas

# %%
s = pd.Series(list('abcaabbc'))
print(s)
# Out:
# 0    a
# 1    b
# 2    c
# 3    a
# 4    a
# 5    b
# 6    b
# 7    c
# dtype: object

# %%
pd.get_dummies(s)
# Out:
#        a      b      c
# 0   True  False  False
# 1  False   True  False
# 2  False  False   True
# 3   True  False  False
# 4   True  False  False
# 5  False   True  False
# 6  False   True  False
# 7  False  False   True

# %% [markdown]
# El siguiente grafico nos permite ver facilmente cual es la distribución del tipo de motor para los diferentes tipos de transmisión (Automática vs Manual). **Ojo**: Para este tipo de gráfico es necesario tener una columna que indique que tipo de categoria es, para luego sumar su cantidad. Lo que vamos a hacer a continuación se conoce como crear variables _dummy_.

# %%
mtcars_dummy = pd.get_dummies(mtcars, columns=['vs'])
mtcars_dummy.head(5)
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec          am  \
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46      Manual
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02      Manual
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61      Manual
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44  Automático
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02  Automático
#
#                    gear  carb
# Mazda RX4             4     4
# Mazda RX4 Wag         4     4
# Datsun 710            4     1
# Hornet 4 Drive        3     1
# Hornet Sportabout     3     2

# %% [markdown]
# ## quiz 6: ¿cuántas operaciones debo hacer para generar el gráfico explicado mas arriba? (recueden queremos saca las cantidades de tipos de motor (vs-Straight, vs-V-shaped) por tipos de transmision(manual, automática)

# %%
from pydataset import data
mtcars = data("mtcars") # Reload mtcars to ensure a clean state
# Re-apply the mapping for 'am' column if it was done previously
mtcars['am'] = mtcars['am'].map({0:'Automático', 1:'Manual'})
# Correctly map 'vs' column to string labels
mtcars['vs'] = mtcars['vs'].map({0: 'V-shaped', 1: 'Straight'})
# Re-create mtcars_dummy with the correct dummy variables for 'vs'
mtcars_dummy = pd.get_dummies(mtcars, columns=['vs'])

mtcars_dummy_grouped = mtcars_dummy.groupby(mtcars_dummy["am"]).agg({'vs_V-shaped':'sum','vs_Straight':'sum'})
mtcars_dummy_grouped
# Out:
#             vs_V-shaped  vs_Straight
# am
# Automático           12            7
# Manual                6            7

# %%
ax =mtcars_dummy_grouped.plot.bar(stacked=True) #true o False?
ax.set_ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
# ## quiz 7: ¿Qué representa el garfico anterior?

# %%
# Para obtener porcentajes vamos a sumar el total de cada columna con:
mtcars_dummy_grouped.sum()
# Out:
# vs_V-shaped    18
# vs_Straight    14
# dtype: int64

# %%
# Creamos un nuevo dataframe pero con formato en porcentaje, esto es simplemente diviendo por el total de vehiculos
mtcars_dummy_grouped_v2 = mtcars_dummy_grouped/ mtcars_dummy_grouped.sum().sum()

#print(mtcars_dummy_grouped)

#print(mtcars_dummy_grouped.sum().sum())

# %%
mtcars_dummy_grouped_v2
# Out:
#             vs_V-shaped  vs_Straight
# am
# Automático       0.3750      0.21875
# Manual           0.1875      0.21875

# %%
ax = mtcars_dummy_grouped_v2.plot.bar(stacked=True)
# Cambia el formato a procentaje
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
#ax.yaxis.set_major_formatter(mtick.NullFormatter())
ax.set_ylabel("count/sum(count)");

# %% [markdown]
# ## Posiciones para las barras
#
# Ya vimos como hacer un gráfico _stacked_, ahora vamos a ver como crear más de una barra.

# %%
# Con rot=0 giramos los labels del eje X
ax = mtcars_dummy_grouped_v2.plot.bar(rot=0)
# Cambia el formato a procentaje
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
ax.set_ylabel("count/sum(count)");

# %%
# Aquí la versión sin porcentajes
ax = mtcars_dummy_grouped.plot.bar(rot=45)
ax.set_ylabel("count");

# %% [markdown]
# ## Más de una barra en Seaborn
#
# Veamos cómo podemos replicar este gráfico en Seaborn, partiendo deel _dataset_ sin las variables _dummy_.

# %%
mtcars.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec        vs  \
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46  V-shaped
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02  V-shaped
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61  Straight
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44  Straight
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02  V-shaped
#
#                            am  gear  carb
# Mazda RX4              Manual     4     4
# Mazda RX4 Wag          Manual     4     4
# Datsun 710             Manual     4     1
# Hornet 4 Drive     Automático     3     1
# Hornet Sportabout  Automático     3     2

# %%
ax = sns.countplot(x="am", hue="vs", data=mtcars)

# %%
ax = sns.countplot(y="am", hue="vs", data=mtcars)

# %%
with plt.xkcd():
    ax = sns.countplot(x="am", hue="vs", data=mtcars)
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.

# %% [markdown]
# ## Distribución del número de cilindros por tipo de auto: automático vs manual
#
# Vamos a ver la distribución del número de cilindros por tipo de auto. Aquí, a pesar de que la variable cyl es cuantitativa (discreta), la vamos a tratar como una variable categorica.

# %%
mtcars.groupby(mtcars['cyl']).size()
# Out:
# cyl
# 4    11
# 6     7
# 8    14
# dtype: int64

# %%
mtcars_dummy_2 = pd.get_dummies(mtcars, columns=['cyl'])
mtcars_dummy_2.head(5)
# Out:
#                     mpg   disp   hp  drat     wt   qsec        vs          am  \
# Mazda RX4          21.0  160.0  110  3.90  2.620  16.46  V-shaped      Manual
# Mazda RX4 Wag      21.0  160.0  110  3.90  2.875  17.02  V-shaped      Manual
# Datsun 710         22.8  108.0   93  3.85  2.320  18.61  Straight      Manual
# Hornet 4 Drive     21.4  258.0  110  3.08  3.215  19.44  Straight  Automático
# Hornet Sportabout  18.7  360.0  175  3.15  3.440  17.02  V-shaped  Automático
#
#                    gear  carb  cyl_4  cyl_6  cyl_8
# Mazda RX4             4     4  False   True  False
# Mazda RX4 Wag         4     4  False   True  False
# Datsun 710            4     1   True  False  False
# Hornet 4 Drive        3     1  False   True  False
# Hornet Sportabout     3     2  False  False   True

# %%
mtcars_dummy_grouped_2 = mtcars_dummy_2.groupby(mtcars_dummy_2["am"]).agg({'cyl_8': 'sum', 'cyl_6': 'sum', 'cyl_4': 'sum'})
mtcars_dummy_grouped_2
# Out:
#             cyl_8  cyl_6  cyl_4
# am
# Automático     12      4      3
# Manual          2      3      8

# %%
ax = mtcars_dummy_grouped_2.plot.bar(stacked=True)
ax.set_ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
# **¿Cuál es la distribución del número de cilindros por tipo de auto (automático vs manual), y por tipo de motor (V-shaped vs Straight)?**
#
# Veamos cómo graficar más de una variable categórica.

# %%
import matplotlib.pyplot as plt

# %%
mtcars_straight = mtcars[mtcars["vs"]=="Straight"]
#notar que el operador - no puede ser parte de un nombre en python.
mtcars_V_shaped = mtcars[mtcars["vs"]=="V-shaped"]

# %%
mtcars_straight_dummy = pd.get_dummies(mtcars_straight, columns=['cyl'])
mtcars_V_shaped_dummy = pd.get_dummies(mtcars_V_shaped, columns=['cyl'])
print(mtcars_straight_dummy)
print(mtcars_straight_dummy.shape)
print(mtcars_V_shaped_dummy)
print(mtcars_V_shaped_dummy.shape)
# Out:
#                  mpg   disp   hp  drat     wt   qsec        vs          am  \
# Datsun 710      22.8  108.0   93  3.85  2.320  18.61  Straight      Manual
# Hornet 4 Drive  21.4  258.0  110  3.08  3.215  19.44  Straight  Automático
# Valiant         18.1  225.0  105  2.76  3.460  20.22  Straight  Automático
# Merc 240D       24.4  146.7   62  3.69  3.190  20.00  Straight  Automático
# Merc 230        22.8  140.8   95  3.92  3.150  22.90  Straight  Automático
# Merc 280        19.2  167.6  123  3.92  3.440  18.30  Straight  Automático
# Merc 280C       17.8  167.6  123  3.92  3.440  18.90  Straight  Automático
# Fiat 128        32.4   78.7   66  4.08  2.200  19.47  Straight      Manual
# Honda Civic     30.4   75.7   52  4.93  1.615  18.52  Straight      Manual
# Toyota Corolla  33.9   71.1   65  4.22  1.835  19.90  Straight      Manual
# Toyota Corona   21.5  120.1   97  3.70  2.465  20.01  Straight  Automático
# Fiat X1-9       27.3   79.0   66  4.08  1.935  18.90  Straight      Manual
# Lotus Europa    30.4   95.1  113  3.77  1.513  16.90  Straight      Manual
# Volvo 142E      21.4  121.0  109  4.11  2.780  18.60  Straight      Manual
#
#                 gear  carb  cyl_4  cyl_6
# Datsun 710         4     1   True  False
# Hornet 4 Drive     3     1  False   True
# Valiant            3     1  False   True
# Merc 240D          4     2   True  False
# Merc 230           4     2   True  False
# Merc 280           4     4  False   True
# Merc 280C          4     4  False   True
# Fiat 128           4     1   True  False
# Honda Civic        4     2   True  False
# Toyota Corolla     4     1   True  False
# Toyota Corona      3     1   True  False
# Fiat X1-9          4     1   True  False
# Lotus Europa       5     2   True  False
# Volvo 142E         4     2   True  False
# (14, 12)
#                       mpg   disp   hp  drat     wt   qsec        vs  \
# Mazda RX4            21.0  160.0  110  3.90  2.620  16.46  V-shaped
# Mazda RX4 Wag        21.0  160.0  110  3.90  2.875  17.02  V-shaped
# Hornet Sportabout    18.7  360.0  175  3.15  3.440  17.02  V-shaped
# Duster 360           14.3  360.0  245  3.21  3.570  15.84  V-shaped
# Merc 450SE           16.4  275.8  180  3.07  4.070  17.40  V-shaped
# Merc 450SL           17.3  275.8  180  3.07  3.730  17.60  V-shaped
# Merc 450SLC          15.2  275.8  180  3.07  3.780  18.00  V-shaped
# Cadillac Fleetwood   10.4  472.0  205  2.93  5.250  17.98  V-shaped
# Lincoln Continental  10.4  460.0  215  3.00  5.424  17.82  V-shaped
# Chrysler Imperial    14.7  440.0  230  3.23  5.345  17.42  V-shaped
# Dodge Challenger     15.5  318.0  150  2.76  3.520  16.87  V-shaped
# AMC Javelin          15.2  304.0  150  3.15  3.435  17.30  V-shaped
# Camaro Z28           13.3  350.0  245  3.73  3.840  15.41  V-shaped
# Pontiac Firebird     19.2  400.0  175  3.08  3.845  17.05  V-shaped
# Porsche 914-2        26.0  120.3   91  4.43  2.140  16.70  V-shaped
# Ford Pantera L       15.8  351.0  264  4.22  3.170  14.50  V-shaped
# Ferrari Dino         19.7  145.0  175  3.62  2.770  15.50  V-shaped
# Maserati Bora        15.0  301.0  335  3.54  3.570  14.60  V-shaped
#
#                              am  gear  carb  cyl_4  cyl_6  cyl_8
# Mazda RX4                Manual     4     4  False   True  False
# Mazda RX4 Wag            Manual     4     4  False   True  False
# Hornet Sportabout    Automático     3     2  False  False   True
# Duster 360           Automático     3     4  False  False   True
# Merc 450SE           Automático     3     3  False  False   True
# Merc 450SL           Automático     3     3  False  False   True
# Merc 450SLC          Automático     3     3  False  False   True
# Cadillac Fleetwood   Automático     3     4  False  False   True
# Lincoln Continental  Automático     3     4  False  False   True
# Chrysler Imperial    Automático     3     4  False  False   True
# Dodge Challenger     Automático     3     2  False  False   True
# AMC Javelin          Automático     3     2  False  False   True
# Camaro Z28           Automático     3     4  False  False   True
# Pontiac Firebird     Automático     3     2  False  False   True
# Porsche 914-2            Manual     5     2   True  False  False
# Ford Pantera L           Manual     5     4  False  False   True
# Ferrari Dino             Manual     5     6  False   True  False
# Maserati Bora            Manual     5     8  False  False   True
# (18, 13)

# %%
#Notar que no existen 8 cyl para el tipo straight
mtcars_straight_dummy.head(5)
# Out:
#                  mpg   disp   hp  drat     wt   qsec        vs          am  \
# Datsun 710      22.8  108.0   93  3.85  2.320  18.61  Straight      Manual
# Hornet 4 Drive  21.4  258.0  110  3.08  3.215  19.44  Straight  Automático
# Valiant         18.1  225.0  105  2.76  3.460  20.22  Straight  Automático
# Merc 240D       24.4  146.7   62  3.69  3.190  20.00  Straight  Automático
# Merc 230        22.8  140.8   95  3.92  3.150  22.90  Straight  Automático
#
#                 gear  carb  cyl_4  cyl_6
# Datsun 710         4     1   True  False
# Hornet 4 Drive     3     1  False   True
# Valiant            3     1  False   True
# Merc 240D          4     2   True  False
# Merc 230           4     2   True  False

# %%
# Notar que la agrupacion debe ser consistente con la existencia de las columnas, en la primera linea, no existen cyl_8
mtcars_straight_dummy_group = mtcars_straight_dummy.groupby(mtcars_straight_dummy["am"]).agg({'cyl_6': 'sum', 'cyl_4': 'sum'})

mtcars_V_shaped_dummy_group = mtcars_V_shaped_dummy.groupby(mtcars_V_shaped_dummy["am"]).agg({'cyl_8': 'sum', 'cyl_6': 'sum', 'cyl_4': 'sum'})

print(mtcars_V_shaped_dummy_group)
print(mtcars_straight_dummy_group)
# Out:
#             cyl_8  cyl_6  cyl_4
# am
# Automático     12      0      0
# Manual          2      3      1
#             cyl_6  cyl_4
# am
# Automático      4      3
# Manual          0      7

# %%
ax = mtcars_dummy_grouped_2.plot.bar(stacked=True)
ax.set_ylabel("count");

# %%
# Primero debemos definir nuestros ejes
fig = plt.figure(figsize=(10,8))
ax1 = plt.subplot(1, 2, 1)
ax1.set_title('Straight')
ax2 = plt.subplot(1, 2, 2)
ax2.set_title('V-Shaped')
# Out:
# Text(0.5, 1.0, 'V-Shaped')

# %%
# Hacemos uso de los subplot para crear nuestras figuras
fig = plt.figure(figsize=(10,8))
ax1 = plt.subplot(1, 2, 1)
ax1.set_title('Straight')
ax1 = mtcars_straight_dummy_group.plot.bar(ax=ax1,stacked=True)
ax1.set_ylabel("count")
ax1.legend(loc='upper right')

ax2 = plt.subplot(1, 2, 2)
ax2.set_title('V-Shaped')
ax2 = mtcars_V_shaped_dummy_group.plot.bar(ax=ax2,stacked=True)
ax2.set_ylabel("count")
ax2.legend(loc='upper right')

# %%
aux = mtcars.groupby([mtcars["am"], mtcars["vs"], mtcars["gear"], mtcars["cyl"]], as_index = False)["mpg"].count()
aux.columns=["am", "vs", "gear", "cyl", "conteo"] # renombramos las columnas
#aux = aux.set_index(["am","vs"])
aux
# Out:
#             am        vs  gear  cyl  conteo
# 0   Automático  Straight     3    4       1
# 1   Automático  Straight     3    6       2
# 2   Automático  Straight     4    4       2
# 3   Automático  Straight     4    6       2
# 4   Automático  V-shaped     3    8      12
# 5       Manual  Straight     4    4       6
# 6       Manual  Straight     5    4       1
# 7       Manual  V-shaped     4    6       2
# 8       Manual  V-shaped     5    4       1
# 9       Manual  V-shaped     5    6       1
# 10      Manual  V-shaped     5    8       2

# %%
automatico_straight = mtcars[(mtcars["am"]=="Automático") & (mtcars["vs"]=="Straight")]
automatico_straight_dummy = pd.get_dummies(automatico_straight, columns=['cyl'])
print(automatico_straight_dummy)
#Notar que solo existen Automático V-shaped de 4 y 6 cyls
automatico_straight_dummy.groupby("gear").agg({"cyl_4": "sum", "cyl_6": "sum"}).plot.bar(stacked=True,color={"cyl_4":"red","cyl_6":"green","cyl_8":"blue"});
# Out:
#                  mpg   disp   hp  drat     wt   qsec        vs          am  \
# Hornet 4 Drive  21.4  258.0  110  3.08  3.215  19.44  Straight  Automático
# Valiant         18.1  225.0  105  2.76  3.460  20.22  Straight  Automático
# Merc 240D       24.4  146.7   62  3.69  3.190  20.00  Straight  Automático
# Merc 230        22.8  140.8   95  3.92  3.150  22.90  Straight  Automático
# Merc 280        19.2  167.6  123  3.92  3.440  18.30  Straight  Automático
# Merc 280C       17.8  167.6  123  3.92  3.440  18.90  Straight  Automático
# Toyota Corona   21.5  120.1   97  3.70  2.465  20.01  Straight  Automático
#
#                 gear  carb  cyl_4  cyl_6
# Hornet 4 Drive     3     1  False   True
# Valiant            3     1  False   True
# Merc 240D          4     2   True  False
# Merc 230           4     2   True  False
# Merc 280           4     4  False   True
# Merc 280C          4     4  False   True
# Toyota Corona      3     1   True  False

# %%
automatico_v_shaped = mtcars[(mtcars["am"]=="Automático")&(mtcars["vs"]=="V-shaped")]
automatico_v_shaped_dummy = pd.get_dummies(automatico_v_shaped, columns=['cyl'])
#Notar que solo existen Automático V-shaped de 8 cyls
automatico_v_shaped_dummy.groupby("gear").agg({"cyl_8":"sum"}).plot.bar(stacked=True,color={"cyl_4":"red","cyl_6":"green","cyl_8":"blue"});

# %%
manual_straight = mtcars[(mtcars["am"]=="Manual")&(mtcars["vs"]=="Straight")]
manual_straight_dummy = pd.get_dummies(manual_straight, columns=['cyl'])
#Notar que solo existen Automático V-shaped de 4 cyls
manual_straight_dummy.groupby("gear").agg({"cyl_4":"sum"}).plot.bar(stacked=True,color={"cyl_4":"red","cyl_6":"green","cyl_8":"blue"});

# %%
manual_v_shaped = mtcars[(mtcars["am"]=="Manual")&(mtcars["vs"]=="V-shaped")]
manual_v_shaped_dummy = pd.get_dummies(manual_v_shaped, columns=['cyl'])
#Notar que solo existen Automático V-shaped de 4, 6 y 8 cyls
manual_v_shaped_dummy.groupby("gear").agg({"cyl_4":"sum","cyl_6":"sum","cyl_8":"sum"}).plot.bar(stacked=True,color={"cyl_4":"red","cyl_6":"green","cyl_8":"blue"});

# %%
fig = plt.figure(figsize=(10,8))
#hspace y wspace nos permite ajustar las distancias entre los subplots
fig.subplots_adjust(hspace=0.4, wspace=0.4)
ax1 = plt.subplot(2, 2, 1)
ax1.set_title('Straight Automático')
ax1= automatico_straight_dummy.groupby("gear").agg({"cyl_4":"sum","cyl_6":"sum"}).plot.bar(ax=ax1,stacked=True,color={"cyl_4":"red","cyl_6":"green","cyl_8":"blue"})
ax1.set_ylabel("count")
ax1.legend(loc = 'upper right')
ax1.set_ylim([0, 12.5])

ax2 = plt.subplot(2, 2, 2)
ax2.set_title('Straight Manual')
ax2= manual_straight_dummy.groupby("gear").agg({"cyl_4":"sum"}).plot.bar(ax=ax2,stacked=True,color={"cyl_4":"red","cyl_6":"green","cyl_8":"blue"})
ax2.set_ylabel("count")
ax2.legend(loc = 'upper right')
ax2.set_ylim([0, 12.5])

ax3 = plt.subplot(2, 2, 3)
ax3.set_title('V-Shaped Automático')
ax3= automatico_v_shaped_dummy.groupby("gear").agg({"cyl_8":"sum"}).plot.bar(ax=ax3,stacked=True,color={"cyl_4":"red","cyl_6":"green","cyl_8":"blue"})
ax3.set_ylabel("count")
ax3.legend(loc = 'upper right')
ax3.set_ylim([0, 12.5])

ax4 = plt.subplot(2, 2, 4)
ax4.set_title('V-Shaped Manual')
ax4 = manual_v_shaped_dummy.groupby("gear").agg({"cyl_4":"sum","cyl_6":"sum","cyl_8":"sum"}).plot.bar(ax=ax4,stacked=True,color={"cyl_4":"red","cyl_6":"green","cyl_8":"blue"})
ax4.set_ylabel("count")
ax4.legend(loc = 'upper right')
ax4.set_ylim([0, 12.5]);
